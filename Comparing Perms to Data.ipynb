# %%
from permutations import *
import pandas as pd
from dateutil.relativedelta import relativedelta

# %%
permutations=pd.read_csv('permutations.csv')
congress = pd.read_csv('congress_main.csv')
congress['TransactionDate'] = pd.to_datetime(congress['TransactionDate'])
returns = pd.read_csv('returns.csv')
returns.index = returns.Date.astype('datetime64[ns]')
returns.drop('Date', axis=1, inplace=True)
congress['Variance']=congress.apply(calculate_variance,axis=1)
congress.head()
# Out:
#    ReportDate TransactionDate Ticker             Representative Transaction  \
# 0  2018-05-15      2018-03-05    WFC  A. Mitchell Jr. McConnell    Purchase
# 1  2018-06-13      2018-06-01    WFC  A. Mitchell Jr. McConnell    Purchase
# 2  2018-09-14      2018-09-06    WFC  A. Mitchell Jr. McConnell    Purchase
# 3  2019-03-06      2019-03-05    WFC  A. Mitchell Jr. McConnell    Purchase
# 4  2019-06-14      2019-06-03    VMC  A. Mitchell Jr. McConnell        Sale
#
#      Amount Party   House            Range  Sentiment  ...   Low_End  \
# 0    1001.0     R  Senate     1001 - 15000        NaN  ...    1001.0
# 1    1001.0     R  Senate     1001 - 15000        NaN  ...    1001.0
# 2    1001.0     R  Senate     1001 - 15000        NaN  ...    1001.0
# 3    1001.0     R  Senate     1001 - 15000        NaN  ...    1001.0
# 4  250001.0     R  Senate  250001 - 500000        NaN  ...  250001.0
#
#    High_End  Adjusted_Low_End  Adjusted_High_End  Running_Portfolio_Low_End  \
# ...

# %%
len(congress)*0.0005
# Out:
# 12.711

# %%
permutations=permutations[['Representative','Times Beat Var Rank']]
permutations=permutations.sort_values(by='Times Beat Var Rank')
print('Bottom 0.05 Percent:')
print(permutations.head(13))
print('Reps who always beat their variance:')
print(permutations[permutations['Times Beat Var Rank']==1000])
# Out:
# Bottom 0.05 Percent:
#           Representative  Times Beat Var Rank
# 68   Nicholas Van Taylor                    0
# 120    John Hickenlooper                   13
# 182         Dan Newhouse                   17
# 2     William R. Keating                   22
# 112      Josh Gottheimer                   25
# 181         Dan Sullivan                   25
# 21        Thomas H. Kean                   29
# 184           Cindy Axne                   33
# 73      Mr. Peter Meijer                   35
# 114     Jonathan Jackson                   40
# 106        Kathy Manning                   44
# 60          Peter Meijer                   48
# 123          John Curtis                   49
# Reps who always beat their variance:
#                Representative  Times Beat Var Rank
# 170              David Perdue                 1000
# 165  Debbie Wasserman Schultz                 1000
# 139       Harley E. Rouda Jr.                 1000
# 177            David A. Trott                 1000
# ...

# %%
ranks=congress.groupby('Representative')['Variance'].mean().sort_index(ascending=False)
ranks=pd.DataFrame(ranks).reset_index()
ranks=ranks.sort_values(by='Variance')
print("Congress's Bottom 0.05 percent Traders (Variance):")
print(ranks.head(13))
print("Congress's Top 0.05 percent Traders (Variance):")
print(ranks.tail(13))
# Out:
# Congress's Bottom 0.05 percent Traders (Variance):
#              Representative   Variance
# 31             Steve Knight   0.334480
# 142             Greg Murphy   1.009604
# 86               Mark Green   9.073960
# 57       Richard Blumenthal  18.741389
# 23   Teresa Leger Fernandez  20.943205
# 87            Mark Dr Green  32.740437
# 82               Matt Gaetz  37.265859
# 14             Tim Burchett  37.350393
# 41          Scott H. Peters  39.221837
# 208        Andrew Garbarino  46.701575
# 210          Adam Kinzinger  53.389219
# 173           David Kustoff  56.208673
# 116              John Thune  71.178832
# Congress's Top 0.05 percent Traders (Variance):
#           Representative      Variance
# 73      Mr. Peter Meijer  17056.005985
# 123          John Curtis  17331.319440
# 143       Greg Gianforte  17684.261195
# 60          Peter Meijer  17864.045550
# 106        Kathy Manning  21904.032338
# 184           Cindy Axne  22521.668235
# ...
